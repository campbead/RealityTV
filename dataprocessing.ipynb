# %%
import pandas as pd

df = pd.read_excel('../data/MainDataSheet.xlsx')

# %%
df
# Out:
#       TV Show  Season  Episode  Cut Number  Total Cuts for contestant  \
# 0   Making It       1        1           1                          1
# 1   Making It       1        1           2                          1
# 2   Making It       1        1           3                          1
# 3   Making It       1        1           4                          1
# 4   Making It       1        1           1                          1
# 5   Making It       1        1           2                          1
# 6   Making It       1        1           3                          1
# 7   Making It       1        1           4                          1
# 8   Making It       1        1           5                          1
# 9   Making It       1        2           1                          1
# 10  Making It       1        2           2                          1
# 11  Making It       1        2           3                          1
# ...

# %%
df.groupby(['Cut Number']).mean()
# Out:
#               Season   Episode  Total Cuts for contestant  \
# Cut Number
# 1           1.583333  3.583333                   1.416667
# 2           1.583333  3.583333                   1.416667
# 3           1.608696  3.652174                   1.391304
# 4           1.538462  3.000000                   1.076923
# 5           1.666667  2.000000                   1.166667
# 6           2.000000  2.000000                   1.000000
# 7           2.000000  2.000000                   1.000000
#
#             Total cuts for all contestants  Total time for contestent  \
# Cut Number
# 1                                 5.125000                   2.265250
# 2                                 5.125000                   2.194854
# 3                                 5.260870                   2.097065
# 4                                 5.846154                   1.591346
# 5                                 7.000000                   1.682167
# ...

# %%
df.groupby(['Were they the winner/loser'])
